# %% [markdown]
# # Explore Dataset: 001-Forbes

# %%
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical Analysis
from scipy import stats

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv('../data/raw/datasets/001_Forbes.csv')
df
# Out:
#       rank                personName   age  finalWorth               category  \
# 0        1                 Elon Musk  50.0      219000             Automotive
# 1        2                Jeff Bezos  58.0      171000             Technology
# 2        3  Bernard Arnault & family  73.0      158000       Fashion & Retail
# 3        4                Bill Gates  66.0      129000             Technology
# 4        5            Warren Buffett  91.0      118000  Finance & Investments
# ...    ...                       ...   ...         ...                    ...
# 2663  2578             Zhang Yuqiang  66.0        1000          Manufacturing
# 2664  2578                Zhou Ruxin  59.0        1000             Technology
# 2665  2578         Wen Zhou & family  57.0        1000          Manufacturing
# 2666  2578      Zhou Yifeng & family  43.0        1000                 Energy
# 2667  2578   Zhuang Kuilong & family  59.0        1000          Manufacturing
#
# ...

# %% [markdown]
# ## Understand the dataset

# %% [markdown]
# ### Understand data structure and types

# %%
df.shape
# Out:
# (2668, 17)

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'category', 'source',
#        'country', 'state', 'city', 'organization', 'selfMade', 'gender',
#        'birthDate', 'title', 'philanthropyScore', 'bio', 'about'],
#       dtype='object')

# %%
df.dtypes
# Out:
# rank                   int64
# personName            object
# age                  float64
# finalWorth             int64
# category              object
# source                object
# country               object
# state                 object
# city                  object
# organization          object
# selfMade                bool
# gender                object
# birthDate             object
# title                 object
# philanthropyScore    float64
# bio                   object
# about                 object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2668, step=1)

# %%
df.describe()
# Out:
#               rank          age     finalWorth  philanthropyScore
# count  2668.000000  2582.000000    2668.000000         396.000000
# mean   1302.919040    64.210689    4762.350075           1.856061
# std     747.807782    13.401258   10540.482258           0.971486
# min       1.000000    19.000000    1000.000000           1.000000
# 25%     665.000000    55.000000    1500.000000           1.000000
# 50%    1292.000000    64.000000    2400.000000           2.000000
# 75%    1929.000000    74.000000    4300.000000           2.000000
# max    2578.000000   100.000000  219000.000000           5.000000

# %% [markdown]
# ## Initial Data Exploration

# %%
df['country'].value_counts()
# Out:
# country
# United States     748
# China             571
# India             159
# Germany           112
# United Kingdom     85
#                  ...
# Portugal            1
# Georgia             1
# Algeria             1
# Colombia            1
# Andorra             1
# Name: count, Length: 73, dtype: int64

# %%
df['country'].nunique()
# Out:
# 73

# %%
df['country'].describe()
# Out:
# count              2655
# unique               73
# top       United States
# freq                748
# Name: country, dtype: object

# %%
df['source']
# Out:
# 0              Tesla, SpaceX
# 1                     Amazon
# 3                  Microsoft
# 4         Berkshire Hathaway
# 5                     Google
#                 ...
# 1591             hedge funds
# 1625             hedge funds
# 1643    financial technology
# 1722         casinos, hotels
# 2408         pharmaceuticals
# Name: source, Length: 153, dtype: object

# %%
df['category'][9]
# Out:
# 'Diversified'

# %%
df.isnull().sum()
# Out:
# rank                    0
# personName              0
# age                    86
# finalWorth              0
# category                0
# source                  0
# country                13
# state                1920
# city                   44
# organization         2316
# selfMade                0
# gender                 16
# birthDate              99
# title                2267
# philanthropyScore    2272
# bio                     0
# about                1106
# dtype: int64

# %%
df['age'].isnull().sum()
# Out:
# 86

# %%
df['age'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2663    False
# 2664    False
# 2665    False
# 2666    False
# 2667    False
# Name: age, Length: 2668, dtype: bool

# %%
df[df['city'].isnull()]
# Out:
#       rank                                  personName   age  finalWorth  \
# 34      35  Beate Heister & Karl Albrecht Jr. & family   NaN       36800
# 36      37                                 Li Ka-shing  93.0       34800
# 65      66                            Guillaume Pousaz  40.0       23000
# 164    163                              Zhang Congyuan  74.0       11700
# 228    227                               Eric Wittouck  75.0        9000
# 368    369         Alejandro Bailleres Gual & siblings  61.0        6700
# 424    424                                  Leo Koguan  67.0        6000
# 489    490                                  Rene Benko  45.0        5400
# 590    586                   Yeow Chor & Yeow Seng Lee   NaN        4800
# 708    709    Juan Domingo Beckmann Legorreta & family  54.0        4100
# 753    728                             Alex Shevchenko  42.0        4000
# 756    728                        Udo & Harald Tschira   NaN        4000
# ...

# %%
df[df['gender'].isnull()]
# Out:
#       rank                                  personName   age  finalWorth  \
# 34      35  Beate Heister & Karl Albrecht Jr. & family   NaN       36800
# 101    102                  Gianluigi & Rafaela Aponte  81.0       16800
# 212    213                             Tom & Judy Love   NaN        9700
# 283    284                     Stewart & Lynda Resnick   NaN        8000
# 303    304                              Bajaj siblings   NaN        7700
# 309    304                              Safra siblings   NaN        7700
# 368    369         Alejandro Bailleres Gual & siblings  61.0        6700
# 782    778                      Vinod & Anil Rai Gupta   NaN        3800
# 822    822         Byju Raveendran and Divya Gokulnath  40.0        3600
# 953    951                       Andrew & Peggy Cherng   NaN        3200
# 1049  1012                       Zhang Xin & Pan Shiyi  56.0        3000
# 1245  1238        Chuchat Petaumpai & Daonapa Petampai  69.0        2500
# ...

# %%
df.shape
# Out:
# (2668, 17)

# %%
df.isnull().sum()
# Out:
# rank                    0
# personName              0
# age                    86
# finalWorth              0
# category                0
# source                  0
# country                13
# state                1920
# city                   44
# organization         2316
# selfMade                0
# gender                 16
# birthDate              99
# title                2267
# philanthropyScore    2272
# bio                     0
# about                1106
# dtype: int64

# %%
df["country"].value_counts()
# Out:
# country
# United States     748
# China             571
# India             159
# Germany           112
# United Kingdom     85
#                  ...
# Portugal            1
# Georgia             1
# Algeria             1
# Colombia            1
# Andorra             1
# Name: count, Length: 73, dtype: int64

# %%
df[df['country'].isnull()]
# Out:
#       rank                         personName   age  finalWorth  \
# 65      66                   Guillaume Pousaz  40.0       23000
# 164    163                     Zhang Congyuan  74.0       11700
# 1102  1096  Karen Virginia Beckmann Legoretta  52.0        2800
# 1282  1238               Christiane Schoeller   NaN        2500
# 1311  1292                Kevin David Lehmann  19.0        2400
# 1661  1645                       Philip Fayer   NaN        1800
# 1733  1729                   Alex Birkenstock  53.0        1700
# 1787  1729                 Renate Sick-Glaser   NaN        1700
# 2090  2076                        Cho Jyh-jer   NaN        1400
# 2394  2324            Ulrich Mommert & family  81.0        1200
# 2442  2324                          Yeh Kuo-I  80.0        1200
# 2562  2448                 Franziska Wuerbser  34.0        1100
# 2640  2578                   Stephan Schnabel   NaN        1000
#
# ...

# %% [markdown]
# ### Visualize the Data

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['age'], kde=True)  # kde=True adds a kernel density estimate
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['gender'], kde=True)  # kde=True adds a kernel density estimate
plt.show()
